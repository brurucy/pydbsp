# %% [markdown]
# # # Stratified negation
#
# `IncrementalDatalogWithNegation` handles body atoms whose predicate
# starts with `!`. This notebook exercises the canonical pattern
# `A(x) :- E(x), !B(x)` — A is derived while B is absent, retracted
# once B appears.

# %%
from pydbsp.algorithms.datalog import IncrementalDatalogWithNegation, saturate
from pydbsp.algorithms import Variable
from pydbsp.history import History
from pydbsp.zset import ZSet

program = ZSet(
    {
        (
            ("A", (Variable("X"),)),
            ("A", (Variable("X"),)),
        ): 1,
        (
            ("A", (Variable("X"),)),
            ("E", (Variable("X"),)),
            ("!B", (Variable("X"),)),
        ): 1,
    }
)

# %% [markdown]
# ## Tick 0: E(0) only
#
# A(0) derives because B(0) is absent.

# %%
circuit = IncrementalDatalogWithNegation()
circuit.edb.push((0,), ZSet({("E", (0,)): 1}))
circuit.program.push((0,), program)
saturate(circuit)

h = History(circuit.observable)
h.try_step()
print("tick 0:", dict(h.at((0,)).inner))
# Out:
# tick 0: {('E', (0,)): 1, ('A', (0,)): 1}

# %% [markdown]
# ## Tick 1: B(0) arrives
#
# A(0) is retracted — B(0) now blocks the rule.

# %%
circuit.edb.push((1,), ZSet({("B", (0,)): 1}))
circuit.program.push((1,), ZSet({}))
saturate(circuit, outer_tick=1)

h.try_step()
cumulative = dict(h.at((0,)).inner)
for fact, w in h.at((1,)).inner.items():
    cumulative[fact] = cumulative.get(fact, 0) + w
cumulative = {k: v for k, v in cumulative.items() if v != 0}
print("cumulative after tick 1:", cumulative)
# Out:
# cumulative after tick 1: {('E', (0,)): 1, ('B', (0,)): 1}
