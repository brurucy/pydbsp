# %% [markdown]
# # Stratified Datalog with negation
#
# This notebook demonstrates `IncrementalDatalogStratified` on two programs that mix positive Datalog with negated atoms. The evaluator stratifies rules by the longest negative-edge chain in the predicate-dependency graph: lower-stratum predicates settle before any rule that negates them runs, so the result is unambiguous.
#
# Ported from the v0.6.0 `stratified_negation.ipynb`. Variables are inline `"?X"` strings, negated atoms are written with a `!` prefix, and the whole program is a single ZSet keyed by `(head, *body)` rule tuples.

# %%
from pydbsp.datalog_stratified import IncrementalDatalogStratified
from pydbsp.zset import ZSet

# %% [markdown]
# ## Transitive complement
#
# We build the transitive closure `T(X, Y)` of a four-edge graph in stratum 0, then negate against it in stratum 1 to derive `not_T(X, Y)` for every pair of nodes that the closure misses. `Node` is also a stratum-0 predicate, projected from the endpoints of `E`. The 18 `not_T` pairs are exactly the 25 ordered pairs over `{0, 1, 2, 3, 4}` minus the 7 pairs in the transitive closure.

# %%
program = ZSet({
    ((("T", ("?X", "?Y")), ("E", ("?X", "?Y")))): 1,
    ((("T", ("?X", "?Z")), ("T", ("?X", "?Y")), ("T", ("?Y", "?Z")))): 1,
    ((("Node", ("?X",)), ("E", ("?X", "?Y")))): 1,
    ((("Node", ("?Y",)), ("E", ("?X", "?Y")))): 1,
    ((
        ("not_T", ("?X", "?Y")),
        ("Node", ("?X",)),
        ("Node", ("?Y",)),
        ("!T", ("?X", "?Y")),
    )): 1,
})
edb = ZSet({
    ("E", (2, 3)): 1,
    ("E", (0, 2)): 1,
    ("E", (0, 1)): 1,
    ("R", (1, 2)): 1,
    ("E", (3, 4)): 1,
})

s = IncrementalDatalogStratified()
s.push_rules(program)
s.push_facts(edb)
result = s.saturate()

not_T_pairs = sorted(fact[1] for fact in result.inner if fact[0] == "not_T")
print(not_T_pairs)
# Out:
# [(0, 0), (1, 0), (1, 1), (1, 2), (1, 3), (1, 4), (2, 0), (2, 1), (2, 2), (3, 0), (3, 1), (3, 2), (3, 3), (4, 0), (4, 1), (4, 2), (4, 3), (4, 4)]

# %% [markdown]
# ## 4-cycle without an overlapping 3-cycle
#
# A single rule looks for ordered 4-tuples `(A, B, C, D)` that form a 4-cycle (the four positive `E` atoms) and that are *not* short-circuited by any of the four chord edges (the four `!E` atoms). The EDB has two patterns:
#
# * The clean 4-cycle `0 → 1 → 2 → 3 → 0`. All four rotations satisfy the rule.
# * A 4-cycle `4 → 5 → 6 → 7 → 4` with an extra `6 → 4` edge. That chord violates the `!E(C, A)` constraint when the rotation aligns the chord with the diagonal, so no tuple over `{4, 5, 6, 7}` survives.

# %%
program = ZSet({
    ((
        ("cycle_4_not_overlapping_cycle_3", ("?A", "?B", "?C", "?D")),
        ("E", ("?A", "?B")),
        ("E", ("?B", "?C")),
        ("!E", ("?A", "?C")),
        ("E", ("?C", "?D")),
        ("!E", ("?B", "?D")),
        ("!E", ("?C", "?A")),
        ("E", ("?D", "?A")),
        ("!E", ("?D", "?B")),
    )): 1,
})
edb = ZSet({
    ("E", (0, 1)): 1,
    ("E", (1, 2)): 1,
    ("E", (2, 3)): 1,
    ("E", (3, 0)): 1,
    ("E", (4, 5)): 1,
    ("E", (5, 6)): 1,
    ("E", (6, 7)): 1,
    ("E", (7, 4)): 1,
    ("E", (6, 4)): 1,
})

s = IncrementalDatalogStratified()
s.push_rules(program)
s.push_facts(edb)
result = s.saturate()

found = sorted(
    fact[1] for fact in result.inner
    if fact[0] == "cycle_4_not_overlapping_cycle_3"
)
print(found)
# Out:
# [(0, 1, 2, 3), (1, 2, 3, 0), (2, 3, 0, 1), (3, 0, 1, 2)]
