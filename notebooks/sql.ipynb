# %% [markdown]
# In this notebook we build the incremental forms of all SQL operators in DBSP, as defined in subsection 4.2 of [the DBSP paper](https://arxiv.org/pdf/2203.16684).
#
# Each operator is a small recipe over the flat 2-D product lattice: push per-outer-tick diffs on 1-D `Input`s, lift them into the 2-D body lattice with `TimeAxisIntroduction`, compose the right operators, and read the incremental output via `Evaluator.at_op(..., (t, 0))`. Inner axis is pinned at 0 because these examples have no fixpoint.

# %%
from pydbsp.core import Time1D, Time2D
from pydbsp.evaluator import Evaluator
from pydbsp.stream import Input
from pydbsp.stream.functions.linear import TimeAxisIntroduction
from pydbsp.stream.zset.operators.binary import DLDDistinct
from pydbsp.zset import ZSet, ZSetAddition


def push_diffs(stream, diffs):
    """Push each ``diff`` dict as a ZSet at successive outer ticks."""
    for t, diff in enumerate(diffs):
        stream.push((t,), ZSet(diff))


def read_diffs(ev, op, n):
    """Read ``n`` outer ticks at inner=0; drop empty diffs."""
    return {t: ev.at_op(op, (t, 0)).inner for t in range(n) if ev.at_op(op, (t, 0)).inner}


# (SELECT * FROM I1) UNION (SELECT * FROM I2)
# Union is ``a + b`` followed by incremental distinct.  Note how
# ``a`` retracts ``3`` at t=2 while ``b`` introduced it at t=1 —
# distinct observes the cumulative ``{3: 0}`` and emits a retraction.
lattice = Time2D
g = ZSetAddition[int]()

a = Input(g, Time1D)
b = Input(g, Time1D)
a_2d = TimeAxisIntroduction(a, g, lattice, axis=1)
b_2d = TimeAxisIntroduction(b, g, lattice, axis=1)
union = DLDDistinct(a_2d + b_2d, g, lattice)

push_diffs(a, [{1: 1}, {2: 1}, {3: -1}])
push_diffs(b, [{2: 1}, {3: 1}, {}])

ev = Evaluator(union)
print(read_diffs(ev, union, 3))

# %%
from pydbsp.stream.zset.operators.linear import Project

# SELECT DISTINCT I.c[0] FROM I
g_in = ZSetAddition[tuple[str, str]]()
g_out = ZSetAddition[str]()

i_in = Input(g_in, Time1D)
i_2d = TimeAxisIntroduction(i_in, g_in, lattice, axis=1)
projection = DLDDistinct(Project(i_2d, lambda x: x[0], g_out), g_out, lattice)

push_diffs(i_in, [{("a", "b"): 1}, {("c", "d"): 1}, {("e", "f"): 1}])
ev = Evaluator(projection)
print(read_diffs(ev, projection, 3))

# %%
from pydbsp.stream.zset.operators.linear import Select

# SELECT DISTINCT * FROM I WHERE p(I.c)
g = ZSetAddition[tuple[str, str]]()

i_in = Input(g, Time1D)
i_2d = TimeAxisIntroduction(i_in, g, lattice, axis=1)
filtering = DLDDistinct(Select(i_2d, lambda x: x[0] == "a"), g, lattice)

push_diffs(i_in, [{("a", "b"): 1}, {("a", "d"): 1}, {("e", "f"): 1}])
ev = Evaluator(filtering)
print(read_diffs(ev, filtering, 3))

# %%
# SELECT DISTINCT f(I.c) FROM I  —  projection by an arbitrary function
g_in = ZSetAddition[tuple[int, str]]()
g_out = ZSetAddition[int]()

i_in = Input(g_in, Time1D)
i_2d = TimeAxisIntroduction(i_in, g_in, lattice, axis=1)
selection = DLDDistinct(Project(i_2d, lambda x: x[0] ** 2, g_out), g_out, lattice)

push_diffs(i_in, [{(1, "b"): 1}, {(2, "d"): 1}, {(3, "f"): 1}])
ev = Evaluator(selection)
print(read_diffs(ev, selection, 3))

# %%
from pydbsp.stream.zset.operators.bilinear import DLDJoin

# SELECT I1.*, I2.* FROM I1, I2   —   pred always true = full cartesian
g_in = ZSetAddition[int]()
g_out = ZSetAddition[tuple[int, int]]()

a_in = Input(g_in, Time1D)
b_in = Input(g_in, Time1D)
a_2d = TimeAxisIntroduction(a_in, g_in, lattice, axis=1)
b_2d = TimeAxisIntroduction(b_in, g_in, lattice, axis=1)

cartesian = DLDJoin(
    a_2d, b_2d,
    lambda l, r: True,
    lambda l, r: (l, r),
    g_out, lattice,
)

push_diffs(a_in, [{1: 1}, {2: 1}, {3: 1}])
push_diffs(b_in, [{1: 1}, {2: 1}, {3: 1}])
ev = Evaluator(cartesian)
print(read_diffs(ev, cartesian, 3))

# %%
# SELECT I1.*, I2.* FROM I1 JOIN I2 ON I1.c1 = I2.c2
g_in = ZSetAddition[tuple[str, str]]()
g_out = ZSetAddition[tuple[tuple[str, str], tuple[str, str]]]()

a_in = Input(g_in, Time1D)
b_in = Input(g_in, Time1D)
a_2d = TimeAxisIntroduction(a_in, g_in, lattice, axis=1)
b_2d = TimeAxisIntroduction(b_in, g_in, lattice, axis=1)

join_ = DLDJoin(
    a_2d, b_2d,
    lambda l, r: l[0] == r[0],
    lambda l, r: (l, r),
    g_out, lattice,
)

push_diffs(a_in, [{("a", "b"): 1}, {("a", "d"): 1}, {("e", "f"): 1}])
push_diffs(b_in, [{("a", "b"): 1}, {("c", "d"): 1}, {("e", "g"): 1}])
ev = Evaluator(join_)
print(read_diffs(ev, join_, 3))

# %%
# (SELECT * FROM I1) INTERSECT (SELECT * FROM I2)
g = ZSetAddition[int]()

a_in = Input(g, Time1D)
b_in = Input(g, Time1D)
a_2d = TimeAxisIntroduction(a_in, g, lattice, axis=1)
b_2d = TimeAxisIntroduction(b_in, g, lattice, axis=1)

intersection = DLDJoin(
    a_2d, b_2d,
    lambda l, r: l == r,
    lambda l, r: l,
    g, lattice,
)

push_diffs(a_in, [{1: 1}, {2: 1}, {3: 1}])
push_diffs(b_in, [{1: 1}, {2: 1}, {3: -1}])
ev = Evaluator(intersection)
print(read_diffs(ev, intersection, 3))

# %%
# SELECT * FROM I1 EXCEPT SELECT * FROM I2   —   (a − b) with incremental distinct
g = ZSetAddition[int]()

a_in = Input(g, Time1D)
b_in = Input(g, Time1D)
a_2d = TimeAxisIntroduction(a_in, g, lattice, axis=1)
b_2d = TimeAxisIntroduction(b_in, g, lattice, axis=1)
difference = DLDDistinct(a_2d - b_2d, g, lattice)

push_diffs(a_in, [{1: 1}, {2: 1}, {3: 1}])
push_diffs(b_in, [{1: 1}, {2: 1}, {4: 1}])
ev = Evaluator(difference)
print(read_diffs(ev, difference, 3))

# %%
from pydbsp.stream import Lift1
from pydbsp.stream.operators.linear import Differentiate, Integrate

# SELECT I.k, SUM(I.v) FROM I GROUP BY I.k
#
# DBSP's ``aggregate`` pattern: integrate the stream of diffs to get
# the cumulative ZSet at each tick, apply the (non-linear) aggregation
# as a pointwise function, then differentiate back to a diff stream.
# No fixpoint here, so everything fits on a 1-D lattice.


def zset_group_sum(z):
    totals: dict = {}
    for (k, v), w in z.inner.items():
        totals[k] = totals.get(k, 0) + v * w
    return ZSet({(k, v): 1 for k, v in totals.items()})


g_in = ZSetAddition[tuple[str, int]]()
g_out = ZSetAddition[tuple[str, int]]()

i_in = Input(g_in, Time1D)
cum = Integrate(i_in, Time1D, axis=0)
agg = Lift1(cum, zset_group_sum, g_out)
agg_diffs = Differentiate(agg, Time1D, axis=0)

push_diffs(
    i_in,
    [
        {("a", 2): 1},
        {("a", 3): 1},
        {("b", 1): 1},
        {("a", 5): -1},
    ],
)

ev = Evaluator(agg_diffs)
for t in range(4):
    d = ev.at_op(agg_diffs, (t,)).inner
    if d:
        print(f"t={t}: {d}")

# %%
# SELECT I.k, MAX(I.v) FROM I GROUP BY I.k
#
# Same pattern as SUM — a different pointwise aggregation function.
# Because MAX is non-linear, a retraction (negative weight) on the
# max-holder properly exposes the new max.


def zset_group_max(z):
    positive_by_key: dict = {}
    for (k, v), w in z.inner.items():
        if w <= 0:
            continue
        cur = positive_by_key.get(k)
        if cur is None or v > cur:
            positive_by_key[k] = v
    return ZSet({(k, v): 1 for k, v in positive_by_key.items()})


g_in = ZSetAddition[tuple[str, int]]()
g_out = ZSetAddition[tuple[str, int]]()

i_in = Input(g_in, Time1D)
cum = Integrate(i_in, Time1D, axis=0)
max_agg = Lift1(cum, zset_group_max, g_out)
max_diffs = Differentiate(max_agg, Time1D, axis=0)

# Start with a values, then retract the ("a", 3) that was added —
# the max for "a" should drop back to 2.
push_diffs(
    i_in,
    [
        {("a", 2): 1},
        {("a", 3): 1},
        {("b", 1): 1},
        {("a", 3): -1},
    ],
)

ev = Evaluator(max_diffs)
for t in range(4):
    d = ev.at_op(max_diffs, (t,)).inner
    if d:
        print(f"t={t}: {d}")
